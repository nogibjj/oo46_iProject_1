# %%
from lib import read_dataset, top_salesperson, most_sold_make, most_sold_model
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Fetch dataset using lib file
working_df = read_dataset()
working_df.head()
# Out:
#        Date     Salesperson          Customer Name   Car Make  Car Model  \
# 0  05/03/22  Aaron Williams  Christopher Macdonald       Ford    Corolla
# 1  06/08/22  Aaron Williams            Tony Wilson       Ford    Corolla
# 2  03/16/23  Aaron Williams           Brian Wagner     Nissan  Silverado
# 3  12/10/22  Aaron Williams         Brandon Walker     Toyota    Corolla
# 4  09/12/22  Aaron Williams         Brianna Knight  Chevrolet      F-150
#
#    Car Year  Sale Price  Commission Rate  Commission Earned
# 0      2020       10618         0.126843            1346.82
# 1      2013       18232         0.126057            2298.27
# 2      2019       44162         0.128188            5661.06
# 3      2018       20474         0.104818            2146.05
# 4      2014       26385         0.104090            2746.42

# %%
# Fetch top sales from lib and print
top_sales_p = top_salesperson()
top_sales_p
# Out:
# Salesperson
# Betty Young         300
# Michelle Coleman    288
# Jane Blake          287
# Aaron Williams       84
# Valerie Nolan        40
# Name: count, dtype: int64

# %%
# Prepare top sales bar chart and plot
fig = plt.figure(figsize = (10, 5))
 

plt.bar(top_sales_p.index, top_sales_p, color ='maroon',
        width = 0.4)

plt.xlabel("Sales Representatives")
plt.ylabel("No. of cars sold")
plt.title("Total Sales Report (2023)")
plt.show()

# %%
# Fetch top sales by car make from lib and print
msc = most_sold_make()
msc
# Out:
# Car Make
# Ford         239
# Chevrolet    195
# Toyota       194
# Nissan       191
# Honda        180
# Name: count, dtype: int64

# %%
# Create a pie chart
fig, ax = plt.subplots(figsize=(12, 8))
ax.pie(msc, labels=msc.index, autopct='%1.1f%%', startangle=90)
ax.axis('equal')
ax.set_title('Distribution of Car Makes')

plt.show()

# %%
 # Fetch top sales by car model from lib and print
msm = most_sold_model()
msm
# Out:
# Car Model
# F-150        215
# Civic        204
# Corolla      199
# Altima       199
# Silverado    182
# Name: count, dtype: int64

# %%
# Prepare and plot top sales by car make chart
fig, ax = plt.subplots(figsize = (10, 5))

ax.barh(msm.index, msm)
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')

# Add Plot Title
ax.set_title('Most Sold Car Models',
             loc ='left', )
ax.set_xlabel('Number Sold')
ax.set_ylabel('Car Models')

plt.show()
